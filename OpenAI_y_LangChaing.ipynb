# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelTroncoso/Agente_Gratis/blob/main/OpenAI_y_LangChaing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cargar la API Key: Esta clave es tu puente para conectarte con OpenAI.

# %%
import openai
openai.api_key = "tu-api-key-aqui"

# %% [markdown]
# Instalación de herramientas esenciales: Instalar Langchain y sus complementos para OpenAI es un paso fundamental para la integración

# %%
# !pip install langchain langchain-openai

# %% [markdown]
# Cargar el modelo GPT-4O: Este modelo es el corazón de tu aplicación para generar interacciones basadas en lenguaje natural.

# %%
import os
# Importamos la función userdata de google.colab para acceder a los secretos
from google.colab import userdata
from langchain_openai import OpenAI

# 🟢 CÓDIGO CORREGIDO: Accede al secreto guardado y lo establece como variable de entorno
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY')

# Inicializar el modelo (ya no lanzará el 401 si la clave es correcta)
model = OpenAI(model="gpt-3.5-turbo-instruct")

# %% [markdown]
# Crear una consulta y obtener respuestas: Proporciona preguntas al modelo para recibir respuestas enriquecidas.

# %%
# Consulta corregida usando .invoke()
question = "Dame el nombre de la mejor plataforma de educación tecnológica y empresarial en español de América Latina."
response = model.invoke(question)

print("--- Respuesta de GPT-3.5 ---")
print(response.strip())
